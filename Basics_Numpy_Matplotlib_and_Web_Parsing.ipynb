# %% [markdown]
# #### Information Storage and Retrieval :: Basics
#
#
# # Topic: Basics - Numpy, Matplotlib, Web Parsing

# %% [markdown]
# ## Jupyter, Python, and our Expectations
#
# We will use iPython in a Jupyter notebook. iPython is just an interactive shell for programming in the Python language. A few years ago, the developers created a generic interactive shell called Jupyter that supports languages beyond just Python. This can be a bit confusing, and we'll add a bit to the confusion by referring to iPython and Jupyter interchangeably in this course.
#
# Python is a fun language and you should be able to pick up the necessary portions as we move along; however, this may require you to spend some extra cycles consulting online documentation, referring to a Python book, or scouring over StackOverflow.
#
# A few basic Python pointers:
# * http://introtopython.org
# * https://docs.python.org/3/tutorial/
# * http://mbakker7.github.io/exploratory_computing_with_python/ [particularly the basic Python language ones]
#
# In general, Python code is often run from standalone Python modules or files; for this class, we will often run Python from here within the Jupyter notebook.

# %%
# this is a comment
# you can execute this cell by hitting shift+enter
# the output will appear immediately below
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Since Jupyter is just an interactive shell around Python, you can define functions. For example:

# %%
def cubed(x):
    """ Return the cube of a  
        value """
    return x ** 3

cubed(3)
# Out:
# 27

# %% [markdown]
# You can even access the filesystem with commands like `ls` or `pwd`

# %% [markdown]
# ## Getting Started with Numpy and matplotlib
#
# In this part, we're going to get familiar with two important libraries -- Numpy and matplotlib.
#
# ### Into to Numpy
# Since Python is an interpreted language, it might not seem like the best choice for data-intensive work. Luckily, almost all of our data workflow stack is built on top of Numpy, a Python library that adds support for large, multi-dimensional arrays and matrices, along with a large library of high-level mathematical functions to operate on these arrays.

# %%
import numpy as np

print("Make a 4 row x 2 column matrix of random numbers")
x = np.random.random((4, 2))
print(x)
print()

print("Add 10 to every element")
x = x + 10
print(x)
print()

print("Get the element at row 3, column 1")
print(x[3, 1])
print()

print("Get the first row")
print(x[0, :])
print()
# Out:
# Make a 4 row x 2 column matrix of random numbers
# [[0.13828965 0.84023893]
#  [0.35116086 0.14032953]
#  [0.40149498 0.49630128]
#  [0.52912233 0.81797616]]
#
# Add 10 to every element
# [[10.13828965 10.84023893]
#  [10.35116086 10.14032953]
#  [10.40149498 10.49630128]
#  [10.52912233 10.81797616]]
#
# Get the element at row 3, column 1
# 10.817976162173062
#
# Get the first row
# [10.13828965 10.84023893]

# %% [markdown]
# Now, it's your turn. Find the **maximum**, **minimum**, and **mean** of the array `x` you just created. This does not require writing a loop. In the code cell below, type `x.m`+`<TAB>`, to find built-in operations that may help you out.

# %%
print("Maximum:")
# please find and print the maximum of the array
# your code here
print(x.max())

print("Minimum:")
# please find and print the minimum of the array
# your code here
print(x.min())

print("Mean:")
# please find and print the mean of the array
# your code here
print(x.mean())
# Out:
# Maximum:
# 10.84023893029798
# Minimum:
# 10.138289648455514
# Mean:
# 10.464364215616882

# %% [markdown]
# That wasy easy! Now, let's see if you can generate 500 numbers from a uniform distribution between 0 and 50,000, inclusive. That is each random number could be 0, 1, 2, ..., 50,000 with equal chance. Please show us the **maximum**, **minimum**, and **mean** of these 500 random numbers. Hint: you can take a look at `np.random`.

# %%
# your code here
# numpy.random.uniform(low=0.0, high=1.0, size=None)
y = np.random.uniform(0,50000,500)
print("Maximum:")
print(y.max())
print("Minimum:")
print(y.min())

print("Mean:")
print(y.mean())
print()
# Out:
# Maximum:
# 49822.59250180735
# Minimum:
# 148.9401042294558
# Mean:
# 25207.082210201115

# %% [markdown]
# ### Intro to matplotlib
# The most widespread Python plotting library is matplotlib. With it, you can create graphs, charts, basic maps, and other data visualizations. Later in the semester, we'll sometimes use `seaborn`, a library built on top of matplotlib that provides even more beautiful charts.
#
# Below, we provide some simple x and y coordinates that are then plotted. You should update the plot to include:
# * a label for the x-axis (call it 'widgets')
# * a label for the y-axis (call it 'price')
# * a label for the x, y1 curve (call it 'Alice')
# * a label for the x, y2 curve (call it 'Bob')
# * a legend in the lower right corner

# %%
# this line prepares IPython for working with matplotlib
# %matplotlib inline  

import matplotlib.pyplot as plt  

x = [0, 1, 2, 3, 4]  
y1 = [10, 12, 10, 10, 12]
y2 = [8, 9, 9, 11, 12]
#plt.plot(x, y1)
#plt.plot(x, y2) 
# your code here (plus you may need to modify the previous two lines)
# matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, **kwargs)
plt.plot(x, y1, label='Alice')
plt.plot(x, y2, label='Bob')
plt.xlabel('widgets')
plt.ylabel('price')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Getting started with File Input & Output
#
# Python can easily handle reading and writing files. As far as Python is concerned, a file is just a string (often very large!) stored on your local file system, that you can read or write, gradually or all together.
#
# ### Writing Files
#
# *open()* returns a file object, and is most commonly used with two arguments: *open(filename, mode)*.

# %%
outFile = open('sample.txt', 'w')
outFile.write('The first line\nThe second line\nThe third line\n')
outFile.close()

# %% [markdown]
# The first line creates a file object, which links Python to your computer’s file system. The first parameter in the file constructor gives the file name, *sample.txt*. The second parameter indicates how you use the file. The 'w' is short for **w**rite. If the file already existed, the old contents are destroyed.
#
# And 'a' opens the file for **a**ppending; any data written to the file is automatically added to the end. 'r+' opens the file for both reading and writing.
#
# The *close* line is essential for Python to make sure everything is really written, and to relinquish control of the file.

# %% [markdown]
# ### Methods of File Objects
#
# To read a file’s contents, call *f.read(size)*, which reads some quantity of data and returns it as a string. *size* is an optional numeric argument. When *size* is omitted or negative, the entire contents of the file will be read and returned.

# %%
outFile = open('sample.txt', 'r')
outFile.read()
# Out:
# 'The first line\nThe second line\nThe third line\n'

# %% [markdown]
# For reading lines from a file, you can loop over the file object. This is memory efficient, fast, and leads to simple code:

# %%
outFile = open('sample.txt', 'r')
for line in outFile:
    print(line)
# Out:
# The first line
#
# The second line
#
# The third line

# %% [markdown]
# It is good practice to use the *with* keyword when dealing with file objects. This has the advantage that the file is properly closed after its suite finishes, even if an exception is raised on the way. It is also much shorter than writing equivalent try-finally blocks:

# %%
with open('sample.txt', 'r') as f:
    outFile = f.read()
outFile
# Out:
# 'The first line\nThe second line\nThe third line\n'

# %%
f.closed
# Out:
# True

# %%
with open('sample.txt', 'a') as f:
    f.write('The fourth line\n')

# %%
with open('sample.txt', 'r') as f:
    print(f.readlines())  # readlines – reads the entire file and returns it as a list of strings
# Out:
# ['The first line\n', 'The second line\n', 'The third line\n', 'The fourth line\n']

# %% [markdown]
# ### Open a Remote File via URL
#
# Python can easily access the content of a webpage via its URL, and print out locally line-by-line without saving a local copy of the file.

# %%
import urllib  # the lib that handles the url stuff
from bs4 import BeautifulSoup
url = "http://courses.cse.tamu.edu/caverlee/csce670/project.html"

# your code here: open the url. Hint: take a look at urllib2.urlopen
# your code here: now print out each line

# fetch url
wordstring = ""
response = urllib.request.urlopen(url)
for line in response:
    soup = BeautifulSoup(line, 'html.parser')
    text = soup.find_all(text=True)
    print(text)
# Out:
# [' ', 'CSCE 670 :: Information Storage and Retrieval :: Spring\n']
# ['2020', ' ', '\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# [' CSCE 670 :: Information Storage and Retrieval :: Spring 2020 ', '\n']
# ['\n']
# ['Back to main page', '\n']
# ['\n']
# ['Project Overview', '\n']
# ['\n']
# ['For the project, you will work in teams of three or four on a problem of \n']
# ['your choosing that is interesting, significant, and relevant to this course. You have great latitude in what you work on, so make it count! Your main requirements are:\n']
# ['\n']
# ['\n']
# [' Your project code must live on github. We prefer it to be public. However, you can claim a private github account (with a .edu email address).\n']
# [' Your project must use some non-trivial data that your team collects. You may choose to sample social media data (e.g., using an API), download an existing collection, write a simple crawler to collect pre-organized data, or write your own custom web crawler.\n']
# [' Your project must implement or build upon at least one core algorithm from a recent research paper published in a venue like SIGIR, WSDM, WWW, etc.  \n']
# ['\n']
# ['\n']
# ['We will hold a project showcase during the final week of class. \n']
# ['\n']
# ['\n']
# ['\n']
# ['Grading Criteria', '\n']
# ['The course project counts for 25% of your final grade. You will receive an overall rating based on the performance of your entire team, as well as an individual rating based on the feedback of your teammate as well as contributions to the project github repo. Typically, the individual rating can bump or depress your project grade by some small delta (say moving a group rating of 85/100 plus or minus 5 points). Rarely, a project score may be depressed significantly if a group member makes only a superficial contribution to a project.\n']
# ['\n']
# ['Your project will be graded based on these key milestones:\n']
# ['\n']
# ['\n']
# [' [10%] Project proposal: Due March 22 (Sunday) by 11:59pm\n']
# [' [50%] Project showcase: in-class April 27 and 28\n']
# [' [40%] Project website: Due April 30 (Thursday) by 11:59pm\n']
# ['\n']
# ['\n']
# ['Recall that your late days are applicable to homework assignments only. All project milestones are due on their respective due date. No late project milestones will be accepted.\n']
# ['\n']
# ['\n']
# ['Project proposal', '\n']
# ['Each group should post a 1-2 page project proposal in PDF to the Piazza course discussion forum. Be sure to start a new thread for your proposal and name the thread "Proposal: [project_name]", where [project_name] is a brief, descriptive name of your project. Your name should be something memorable! \n']
# ['\n']
# ['\n']
# ['\n']
# ['A proposal should address the following issues:\n']
# ['\n']
# ['\n']
# ['What is your research question? Clearly define the research problem/question.\n']
# ['Why is this an interesting question to ask and why would we care about the answer to this question or a solution to the problem.\n']
# ['Has any existing research work tried to answer the same or a similar question, and if so, what is still unknown?\n']
# ['How do you plan to work out the answer to the question. (At the proposal stage, you are only expected to have a sketch of your methods.)\n']
# ['How would you evaluate your solution. That is, how do you plan to demonstrate that your solution/answer is good or is reasonable.\n']
# ['A rough timeline to show when you expect to finish what. List a couple of milestones.\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['\n']
# ['Project showcase', '\n']
# ['We will host a project showcase during our last week of class. \n']
# ['\n']
# ['On Monday, April 27 and Tuesday, April 28 we will hold an in-class POSTER SESSION. \n']
# ['\n']
# ['All teams must create a poster. Your poster should be MAX 30 inches horizontal by 40 inches vertical. Your poster should be structured somewhat like your website -- that is, you should provide a motivation, your approach (technical details), what you learned, what is next. You can print your poster in the department. Please use ', 'this printer form', ' if you want me to pay for your poster. We will have posterboards and easels set up in the classroom.\n']
# ['\n']
# ['Be sure to highlight the key technical innovations, findings, takeaways. Impress us! This is your chance.\n']
# ['\n']
# ['\n']
# ['\n']
# ['Project website (post link to Piazza)', '\n']
# ['Your team should create a public website that shows off your project. You must use a well-known hosting service -- e.g., Google Sites, Github Pages, Wix (ugh, not my favorite) -- so that we have some assurances your site will not disappear. Your site should essentially be a web-based version of a project report. So, we would expect to see the big questions and takeaways of your project.\n']
# ['\n']
# ['\n']
# ['Introduction / problem background / motivation -- what is the research question? Why is it important?\n']
# ['Related work -- what existing work is there? Include links. What is the difference with what you propose?\n']
# ['Proposed solution / methods used -- give us the technical details about what you have done.\n']
# ['Evaluation and analysis of results -- what did you discover? \n']
# ['Conclusions / discussion -- What was challenging about the project? What would you like to do next? What are the open issues?\n']
# ['\n']
# ['\n']
# ['Your website should also include: \n']
# ['\n']
# ['Link to your github repository.\n']
# ['The data you used (raw or possibly a link to a cloud storage provider).\n']
# ['Link to your poster (PDF or similar).\n']
# ['\n']
# ['\n']
# ['\n']
# [' ', ' ', '\n']
# ['\n']
# []

# %% [markdown]
# ## Counting Word Frequency
#
# One of the most fundamental tasks in information retrieval is to count the frequency of each word in a document.
#
# In the following example, we start with a string and split it into a list. We then create an (initially empty) list called *wordfreq*, go through each word in the *wordlist*, and count the number of times that word appears in the whole list. We then add each word’s count to our wordfreq list. Using the *zip* operation, we are able to match the first word of the word list with the first number in the frequency list, the second word and second frequency, and so on. We end up with a list of word and frequency pairs. The *str* function converts any object to a string so that it can be printed.

# %%
wordstring = 'it was the best of times it was the worst of times '
wordstring += 'it was the age of wisdom it was the age of foolishness'

wordlist = wordstring.split()

wordfreq = []
for w in wordlist:
    wordfreq.append(wordlist.count(w))

print("String\n" + wordstring +"\n")
print("List\n" + str(wordlist) + "\n")
print("Frequencies\n" + str(wordfreq) + "\n")
print("Pairs\n" + str(dict(zip(wordlist, wordfreq))))
# Out:
# String
# it was the best of times it was the worst of times it was the age of wisdom it was the age of foolishness
#
# List
# ['it', 'was', 'the', 'best', 'of', 'times', 'it', 'was', 'the', 'worst', 'of', 'times', 'it', 'was', 'the', 'age', 'of', 'wisdom', 'it', 'was', 'the', 'age', 'of', 'foolishness']
#
# Frequencies
# [4, 4, 4, 1, 4, 2, 4, 4, 4, 1, 4, 2, 4, 4, 4, 2, 4, 1, 4, 4, 4, 2, 4, 1]
#
# Pairs
# {'it': 4, 'was': 4, 'the': 4, 'best': 1, 'of': 4, 'times': 2, 'worst': 1, 'age': 2, 'wisdom': 1, 'foolishness': 1}

# %% [markdown]
# Now, your job is to open up the url we mentioned a few cells above. Then output the word-frequency pairs in that url, sorted in order of descending frequency. In the case of ours Dickens example here, the output would look something like: [('of', 4), ('it', 4), ('the', 4), ('was', 4), ('age', 2), ('times', 2), ('foolishness', 1), ('worst', 1), ('wisdom', 1), ('best', 1)].
#
# Your job is to output a the word-frequency pairs for the url.

# %%
# your code here
import urllib  # the lib that handles the url stuff
url = "http://courses.cse.tamu.edu/caverlee/csce670/project.html"

def sortFreqDict(freqdict):
    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    return aux

from bs4 import BeautifulSoup
wordstring = ""
response = urllib.request.urlopen(url)
for line in response:
    soup = BeautifulSoup(line, 'html.parser')
    text = soup.find_all(text=True)
    wordstring += str(text).strip('[]')

wordlist = wordstring.split()
wordfreq = [wordlist.count(w) for w in wordlist] # a list comprehension
worddic = dict(list(zip(wordlist, wordfreq)))
aux = [(worddic[key], key) for key in worddic]
aux.sort()
aux.reverse()
aux = [t[::-1] for t in aux]
print (aux)
#print("String\n" + wordstring +"\n")
#print("List\n" + str(wordlist) + "\n")
#print("Frequencies\n" + str(wordfreq) + "\n")
#print("Pairs\n" + str(aux))
# Out:
# [('to', 28), ('a', 28), ('the', 25), ('your', 23), ('you', 16), ('project', 14), ('of', 14), ('is', 13), ('and', 11), ('or', 10), ('will', 9), ('what', 9), ('should', 9), ('be', 8), ('Your', 8), ('--', 8), ('that', 7), ('work', 6), ('on', 6), ('in', 6), ('an', 6), ("',", 6), ('research', 5), ('must', 5), ('have', 5), ('You', 5), ('would', 4), ('website', 4), ('we', 4), ('rating', 4), ('proposal', 4), ('poster', 4), ('by', 4), ('as', 4), ('are', 4), ('What', 4), ('April', 4), ('::', 4), ('/', 4), ("'", 4), ('use', 3), ('this', 3), ('some', 3), ('name', 3), ('like', 3), ('it', 3), ('if', 3), ('group', 3), ('github', 3), ('for', 3), ('existing', 3), ('do', 3), ('data', 3), ('can', 3), ('based', 3), ('answer', 3), ('about', 3), ('Project', 3), ('write', 2), ('well', 2), ('week', 2), ('used', 2), ('thread', 2), ('technical', 2), ('teams', 2), ('team', 2), ('sure', 2), ('solution', 2), ('so', 2), ('site', 2), ('showcase', 2), ('question?', 2), ('question', 2), ('project.', 2), ('problem', 2), ('poster.', 2), ('plan', 2), ('only', 2), ('not', 2), ('milestones', 2), ('may', 2), ('main', 2), ('link', 2), ('late', 2), ('key', 2), ('is,', 2), ('individual', 2), ('inches', 2), ('in-class', 2), ('hold', 2), ('final', 2), ('expect', 2), ('during', 2), ('due', 2), ('discussion', 2), ('create', 2), ('course', 2), ('class.', 2), ('We', 2), ('Storage', 2), ('Retrieval', 2), ('Information', 2), ('Due', 2), ('670', 2), ('30', 2), ('27', 2), ('with', 1), ('why', 1), ('where', 1), ('when', 1), ('what.', 1), ('well-known', 1), ('website:', 1), ('web-based', 1), ('web', 1), ('was', 1), ('want', 1), ('vertical.', 1), ('version', 1), ('venue', 1), ('using', 1), ('us!', 1), ('us', 1), ('upon', 1), ('up', 1), ("unknown?\\n''How", 1), ('tried', 1), ('timeline', 1), ('three', 1), ('these', 1), ('there?', 1), ('their', 1), ('teammate', 1), ('team,', 1), ('takeaways.', 1), ('takeaways', 1), ('superficial', 1), ('structured', 1), ('storage', 1), ('still', 1), ('start', 1), ('stage,', 1), ('somewhat', 1), ('something', 1), ('solution/answer', 1), ('solution.', 1), ('social', 1), ('so,', 1), ('small', 1), ('sketch', 1), ('simple', 1), ("similar).\\n''\\n''\\n''\\n''", 1), ('similar', 1), ('significantly', 1), ('significant,', 1), ('shows', 1), ('showcase:', 1), ("showcase',", 1), ('show', 1), ('set', 1), ('service', 1), ('see', 1), ('score', 1), ('sample', 1), ('same', 1), ('rough', 1), ('results', 1), ('respective', 1), ('requirements', 1), ("repository.\\n''The", 1), ('report.', 1), ('repo.', 1), ('relevant', 1), ('recent', 1), ('receive', 1), ("reasonable.\\n''A", 1), ('questions', 1), ('question.', 1), ('question,', 1), ('published', 1), ('public.', 1), ('public', 1), ("provider).\\n''Link", 1), ('provide', 1), ("propose?\\n''Proposed", 1), ('proposal:', 1), ("proposal',", 1), ('project?', 1), ("project.\\n''\\n''\\n''Introduction", 1), ("project.\\n''\\n''Your", 1), ('project,', 1), ("problem/question.\\n''Why", 1), ("problem.\\n''Has", 1), ('private', 1), ('printer', 1), ('print', 1), ('prefer', 1), ('pre-organized', 1), ('posterboards', 1), ('post', 1), ('possibly', 1), ('points).', 1), ('plus', 1), ('performance', 1), ('pay', 1), ('paper', 1), ("page',", 1), ('page', 1), ('own', 1), ('overall', 1), ('out', 1), ('our', 1), ('open', 1), ('only.', 1), ('one', 1), ('on,', 1), ('off', 1), ('non-trivial', 1), ('next?', 1), ('next.', 1), ('new', 1), ('my', 1), ('moving', 1), ('motivation,', 1), ('motivation', 1), ('minus', 1), ("milestones:\\n''\\n''\\n''", 1), ("milestones.\\n''\\n''\\n''\\n''\\n''\\n''\\n''\\n''\\n''\\n''\\n''\\n''Project", 1), ("methods.)\\n''How", 1), ('methods', 1), ('memorable!', 1), ('member', 1), ('media', 1), ('me', 1), ('makes', 1), ('make', 1), ('live', 1), ('links.', 1), ('least', 1), ('learned,', 1), ('latitude', 1), ('last', 1), ("issues?\\n''\\n''\\n''Your", 1), ("issues:\\n''\\n''\\n''What", 1), ('interesting,', 1), ('interesting', 1), ('innovations,', 1), ('include:', 1), ("important?\\n''Related", 1), ('implement', 1), ('how' ...
